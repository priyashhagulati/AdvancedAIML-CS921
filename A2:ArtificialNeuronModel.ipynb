# %% [markdown]
# <a href="https://colab.research.google.com/github/priyashhagulati/AdvancedAIML-CS921/blob/main/A2%3AArtificialNeuronModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def OR_gate (x1, x2):
  w1=1.0
  w2= 1.0
  b = -0.5
  z = w1*x1+w2*x2+b
  if z<0:
    y=0
  else:
    y=1
  return y
y_pred = OR_gate(1,0)
print(y_pred)
# Out:
# 1

# %%
def NAND_gate (x1, x2):
  w1=-1.0
  w2= 1.0
  b = 0.5
  z = w1*x1+w2*x2+b
  if z<0:
    y=0
  else:
    y=1
  return y
y_pred = NAND_gate(0,0)
print(y_pred)
# Out:
# 1

# %%
def AND_gate (x1, x2):
  w1=1.0
  w2= 1.0
  b = -1.5
  z = w1*x1+w2*x2+b
  if z<0:
    y=0
  else:
    y=1
  return y
y_pred = AND_gate(1,1)
print(y_pred)
# Out:
# 1

# %%
def NOR_gate (x1, x2):
  w1=-1.0
  w2= -1.0
  b = 0.5
  z = w1*x1+w2*x2+b
  if z<0:
    y=0
  else:
    y=1
  return y
y_pred = NOR_gate(1,1)
print(y_pred)
# Out:
# 0

# %% [markdown]
# ###Task 2: Implementation of XOR and XNOR

# %%
def XOR_gate(x1, x2):
  y1 = OR_gate(x1, x2)
  y2 = NAND_gate(x1, x2)
  y3 = AND_gate(y1, y2)
  return y3
y_pred = XOR_gate(1,0)
print(y_pred)
# Out:
# 0

# %%
def XOR_gate_3(x1, x2, x3):
  y1 = XOR_gate(x1, x2)
  y_pred = XOR_gate(y1, x3)
  return y_pred
y_pred = XOR_gate_3(1,0,1)
print(y_pred)
# Out:
# 1

# %% [markdown]
# ### Task 3: Computation and plotting of derivative of activation function

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def sigmoid_derivative(x):
    return sigmoid(x) * (1 - sigmoid(x))

# Generate a range of x values
x_values = np.linspace(-5, 5, 100)

# Calculate y values for sigmoid and its derivative
sigmoid_y = sigmoid(x_values)
sigmoid_derivative_y = sigmoid_derivative(x_values)

# Plot the sigmoid function and its derivative
plt.figure(figsize=(10, 6))
plt.plot(x_values, sigmoid_y, label='Sigmoid Function')
plt.plot(x_values, sigmoid_derivative_y, label='Derivative of Sigmoid Function', linestyle='--')
plt.title('Sigmoid Function and Its Derivative')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()
